# %% [markdown]
# <a href="https://colab.research.google.com/github/ohaanika/attention-interpretability/blob/master/retain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Before running any cells, reset all runtimes and ensure runtime type set to "GPU"

# %%
# !pip install git+https://github.com/avolkov1/keras_experiments/
# !git clone https://github.com/ohaanika/attention-interpretability.git
# %cd attention-interpretability
# Out:
# Collecting git+https://github.com/avolkov1/keras_experiments/
#   Cloning https://github.com/avolkov1/keras_experiments/ to /tmp/pip-req-build-8upuj8ma
#   Running command git clone -q https://github.com/avolkov1/keras_experiments/ /tmp/pip-req-build-8upuj8ma
# Requirement already satisfied (use --upgrade to upgrade): keras-exp==1.0 from git+https://github.com/avolkov1/keras_experiments/ in /usr/local/lib/python3.6/dist-packages
# Building wheels for collected packages: keras-exp
#   Building wheel for keras-exp (setup.py) ... done
#   Created wheel for keras-exp: filename=keras_exp-1.0-cp36-none-any.whl size=34438 sha256=30aa0d1c9edb2adc90dcfb5d20593c878711186a30aaa4fb117c38edefe0f8ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xfg1wdq8/wheels/b5/72/fc/623a87c88f1705c992204d571a8831a80c35240f7041a941e4
# Successfully built keras-exp
# Cloning into 'attention-interpretability'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 305 (delta 90), reused 153 (delta 66), pack-reused 122
# Receiving objects: 100% (305/305), 95.85 MiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# Checking out files: 100% (136/136), done.
# /content/attention-interpretability/attention-interpretability/attention-interpretability/attention-interpretability/attention-interpretability

# %%
#!python3 retain_preprocess.py

# %%
# !python3 retain_train.py --num_codes=150850 --epochs=7
# Out:
# Using TensorFlow backend.
# Reading Data
# Creating Model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From retain_train.py:232: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From retain_train.py:234: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-05 05:21:41.219047: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-12-05 05:21:41.219298: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a14bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:21:41.219351: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-12-05 05:21:41.221184: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-05 05:21:41.302614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.303594: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a14a00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:21:41.303667: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-12-05 05:21:41.303879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.304630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:21:41.304948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:21:41.306765: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:21:41.308715: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:21:41.309040: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:21:41.310676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:21:41.311427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:21:41.317621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:21:41.317736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.318588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.319236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:21:41.319310: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:21:41.321143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:21:41.321174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:21:41.321186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:21:41.321293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.322044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.322691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2019-12-05 05:21:41.323649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.324293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:21:41.324355: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:21:41.324396: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:21:41.324427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:21:41.324468: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:21:41.324496: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:21:41.324524: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:21:41.324563: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:21:41.324623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.325307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.326511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:21:41.326564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:21:41.326590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:21:41.326608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:21:41.326882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.328026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.330157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2019-12-05 05:21:41.330807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.332279: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:21:41.332373: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:21:41.332437: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:21:41.332496: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:21:41.332563: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:21:41.332610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:21:41.332647: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:21:41.332684: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:21:41.333458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.334156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.334862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:21:41.334902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:21:41.334924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:21:41.334943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:21:41.335054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.335758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:21:41.336405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training Model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2019-12-05 05:21:45.759925: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:21:45.939182: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 1094/1094 [==============================] - 104s 95ms/step - loss: 0.6436 - acc: 0.5938
#
# Epoch: 0 - ROC-AUC: 0.919925 PR-AUC: 0.918428

# %%
# !python3 retain_evaluation.py
# Out:
# Using TensorFlow backend.
# Loading Model and Extracting Parameters
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From retain_evaluation.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From retain_evaluation.py:22: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-05 05:23:43.692777: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-12-05 05:23:43.693015: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1beabc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:23:43.693057: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-12-05 05:23:43.695139: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-05 05:23:43.754760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.755739: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1bead80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:23:43.755785: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-12-05 05:23:43.755942: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.756725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:23:43.757104: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:23:43.759068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:23:43.760863: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:23:43.761364: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:23:43.763081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:23:43.764284: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:23:43.768691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:23:43.768788: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.769490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.770087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:23:43.770153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:23:43.771634: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:23:43.771663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:23:43.771677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:23:43.771788: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.772546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:43.773437: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2019-12-05 05:23:48.638523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:48.639254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:23:48.639350: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:23:48.639381: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:23:48.639409: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:23:48.639434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:23:48.639457: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:23:48.639520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:23:48.639578: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:23:48.639648: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:48.640309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:48.640950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:23:48.640987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:23:48.641001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:23:48.641010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:23:48.641105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:48.641764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:23:48.642394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Reading Data
# Predicting the probabilities
# 2019-12-05 05:23:49.416743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:23:49.588527: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 469/469 [==============================] - 10s 21ms/step
# Evaluating
# ROC Curve saved to roc.png
# Precision-Recall Curve saved to pr.png
# Lift-Recall Curve saved to lift.png
# Probability Calibration Curves saved to calibration.png

# %%
# !python3 retain_interpretations.py
# Out:
# Using TensorFlow backend.
# Loading Model and Extracting Parameters
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From retain_interpretations.py:16: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From retain_interpretations.py:18: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-05 05:24:06.327459: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-12-05 05:24:06.327695: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1468bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:24:06.327731: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-12-05 05:24:06.329729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-05 05:24:06.388273: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.389145: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1468d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-12-05 05:24:06.389198: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-12-05 05:24:06.389416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.390183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-05 05:24:06.390584: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:24:06.392539: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:24:06.394459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-05 05:24:06.394838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-05 05:24:06.396732: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-05 05:24:06.397937: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-05 05:24:06.402516: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-05 05:24:06.402621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.403351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.403955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-05 05:24:06.404030: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-05 05:24:06.405276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-05 05:24:06.405304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-05 05:24:06.405343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-05 05:24:06.405456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.406174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-05 05:24:06.406901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Model bias: [-0.30632052]
# Reading Data
# 2019-12-05 05:24:12.568210: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-05 05:24:12.750254: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 469/469 [==============================] - 10s 21ms/step
# Input Patient Order Number: 0
# Patients probability: 0.8668150305747986
# Output predictions? (y/n): y
#       status  ... to_event
# 8  Diagnosed  ...        0
# 7  Diagnosed  ...        0
# 0  Diagnosed  ...        0
# 5  Diagnosed  ...        0
# 1  Diagnosed  ...        0
# 9  Diagnosed  ...        0
# 6  Diagnosed  ...        0
# 3  Diagnosed  ...        0
# 2  Diagnosed  ...        0
# 4  Diagnosed  ...        0
#
# [10 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...        1
# 1  Diagnosed  ...        1
# 5  Diagnosed  ...        1
# 0  Diagnosed  ...        1
# 4  Diagnosed  ...        1
# 3  Diagnosed  ...        1
#
# [6 rows x 5 columns]
#       status  ... to_event
# 5  Diagnosed  ...        2
# 4  Diagnosed  ...        2
# 1  Diagnosed  ...        2
# 6  Diagnosed  ...        2
# 3  Diagnosed  ...        2
# 8  Diagnosed  ...        2
# 0  Diagnosed  ...        2
# 7  Diagnosed  ...        2
# 2  Diagnosed  ...        2
#
# [9 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...        3
# 5   Diagnosed  ...        3
# 3   Diagnosed  ...        3
# 8   Diagnosed  ...        3
# 0   Diagnosed  ...        3
# 7   Diagnosed  ...        3
# 4   Diagnosed  ...        3
# 10  Diagnosed  ...        3
# 2   Diagnosed  ...        3
# 9   Diagnosed  ...        3
# 6   Diagnosed  ...        3
#
# [11 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...        4
# 7   Diagnosed  ...        4
# 0   Diagnosed  ...        4
# 11  Diagnosed  ...        4
# 5   Diagnosed  ...        4
# 10  Diagnosed  ...        4
# 3   Diagnosed  ...        4
# 4   Diagnosed  ...        4
# 9   Diagnosed  ...        4
# 8   Diagnosed  ...        4
# 2   Diagnosed  ...        4
# 6   Diagnosed  ...        4
#
# [12 rows x 5 columns]
#       status  ... to_event
# 5  Diagnosed  ...        5
# 1  Diagnosed  ...        5
# 0  Diagnosed  ...        5
# 4  Diagnosed  ...        5
# 2  Diagnosed  ...        5
# 3  Diagnosed  ...        5
#
# [6 rows x 5 columns]
#        status  ... to_event
# 7   Diagnosed  ...        6
# 5   Diagnosed  ...        6
# 12  Diagnosed  ...        6
# 14  Diagnosed  ...        6
# 1   Diagnosed  ...        6
# 10  Diagnosed  ...        6
# 15  Diagnosed  ...        6
# 6   Diagnosed  ...        6
# 0   Diagnosed  ...        6
# 11  Diagnosed  ...        6
# 3   Diagnosed  ...        6
# 2   Diagnosed  ...        6
# 4   Diagnosed  ...        6
# 9   Diagnosed  ...        6
# 13  Diagnosed  ...        6
# 8   Diagnosed  ...        6
#
# [16 rows x 5 columns]
#       status  ... to_event
# 8  Diagnosed  ...        7
# 7  Diagnosed  ...        7
# 3  Diagnosed  ...        7
# 5  Diagnosed  ...        7
# 2  Diagnosed  ...        7
# 4  Diagnosed  ...        7
# 9  Diagnosed  ...        7
# 1  Diagnosed  ...        7
# 0  Diagnosed  ...        7
# 6  Diagnosed  ...        7
#
# [10 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...        8
# 7  Diagnosed  ...        8
# 6  Diagnosed  ...        8
# 4  Diagnosed  ...        8
# 0  Diagnosed  ...        8
# 1  Diagnosed  ...        8
# 3  Diagnosed  ...        8
# 8  Diagnosed  ...        8
# 5  Diagnosed  ...        8
#
# [9 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...        9
# 3  Diagnosed  ...        9
# 1  Diagnosed  ...        9
# 0  Diagnosed  ...        9
#
# [4 rows x 5 columns]
#       status  ... to_event
# 6  Diagnosed  ...       10
# 0  Diagnosed  ...       10
# 7  Diagnosed  ...       10
# 2  Diagnosed  ...       10
# 5  Diagnosed  ...       10
# 1  Diagnosed  ...       10
# 3  Diagnosed  ...       10
# 4  Diagnosed  ...       10
#
# [8 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       11
# 1  Diagnosed  ...       11
# 4  Diagnosed  ...       11
# 3  Diagnosed  ...       11
# 5  Diagnosed  ...       11
# 2  Diagnosed  ...       11
#
# [6 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...       12
# 11  Diagnosed  ...       12
# 8   Diagnosed  ...       12
# 3   Diagnosed  ...       12
# 9   Diagnosed  ...       12
# 5   Diagnosed  ...       12
# 7   Diagnosed  ...       12
# 10  Diagnosed  ...       12
# 2   Diagnosed  ...       12
# 6   Diagnosed  ...       12
# 0   Diagnosed  ...       12
# 4   Diagnosed  ...       12
#
# [12 rows x 5 columns]
#       status  ... to_event
# 5  Diagnosed  ...       13
# 1  Diagnosed  ...       13
# 4  Diagnosed  ...       13
# 3  Diagnosed  ...       13
# 0  Diagnosed  ...       13
# 2  Diagnosed  ...       13
#
# [6 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...       14
# 13  Diagnosed  ...       14
# 10  Diagnosed  ...       14
# 4   Diagnosed  ...       14
# 14  Diagnosed  ...       14
# 15  Diagnosed  ...       14
# 3   Diagnosed  ...       14
# 9   Diagnosed  ...       14
# 11  Diagnosed  ...       14
# 2   Diagnosed  ...       14
# 5   Diagnosed  ...       14
# 8   Diagnosed  ...       14
# 12  Diagnosed  ...       14
# 0   Diagnosed  ...       14
# 6   Diagnosed  ...       14
# 7   Diagnosed  ...       14
#
# [16 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       15
# 0  Diagnosed  ...       15
# 2  Diagnosed  ...       15
# 4  Diagnosed  ...       15
# 3  Diagnosed  ...       15
#
# [5 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       16
# 2  Diagnosed  ...       16
# 4  Diagnosed  ...       16
# 3  Diagnosed  ...       16
# 6  Diagnosed  ...       16
# 5  Diagnosed  ...       16
# 0  Diagnosed  ...       16
#
# [7 rows x 5 columns]
#       status  ... to_event
# 4  Diagnosed  ...       17
# 6  Diagnosed  ...       17
# 2  Diagnosed  ...       17
# 0  Diagnosed  ...       17
# 8  Diagnosed  ...       17
# 5  Diagnosed  ...       17
# 9  Diagnosed  ...       17
# 3  Diagnosed  ...       17
# 7  Diagnosed  ...       17
# 1  Diagnosed  ...       17
#
# [10 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       18
# 1  Diagnosed  ...       18
#
# [2 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...       19
# 1  Diagnosed  ...       19
# 0  Diagnosed  ...       19
#
# [3 rows x 5 columns]
# Input Patient Order Number: 2
# Patients probability: 0.42431414127349854
# Output predictions? (y/n): y
#       status  ... to_event
# 0  Diagnosed  ...        0
#
# [1 rows x 5 columns]
#       status  ... to_event
# 7  Diagnosed  ...        1
# 0  Diagnosed  ...        1
# 3  Diagnosed  ...        1
# 1  Diagnosed  ...        1
# 6  Diagnosed  ...        1
# 5  Diagnosed  ...        1
# 4  Diagnosed  ...        1
# 2  Diagnosed  ...        1
#
# [8 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...        2
#
# [1 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...        3
# 1  Diagnosed  ...        3
#
# [2 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...        4
# 5  Diagnosed  ...        4
# 2  Diagnosed  ...        4
# 3  Diagnosed  ...        4
# 0  Diagnosed  ...        4
# 4  Diagnosed  ...        4
#
# [6 rows x 5 columns]
#        status  ... to_event
# 6   Diagnosed  ...        5
# 13  Diagnosed  ...        5
# 0   Diagnosed  ...        5
# 4   Diagnosed  ...        5
# 7   Diagnosed  ...        5
# 1   Diagnosed  ...        5
# 3   Diagnosed  ...        5
# 12  Diagnosed  ...        5
# 8   Diagnosed  ...        5
# 9   Diagnosed  ...        5
# 5   Diagnosed  ...        5
# 2   Diagnosed  ...        5
# 10  Diagnosed  ...        5
# 11  Diagnosed  ...        5
#
# [14 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...        6
# 6  Diagnosed  ...        6
# 0  Diagnosed  ...        6
# 4  Diagnosed  ...        6
# 5  Diagnosed  ...        6
# 3  Diagnosed  ...        6
# 2  Diagnosed  ...        6
#
# [7 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...        7
# 1  Diagnosed  ...        7
# 2  Diagnosed  ...        7
# 3  Diagnosed  ...        7
#
# [4 rows x 5 columns]
#        status  ... to_event
# 10  Diagnosed  ...        8
# 3   Diagnosed  ...        8
# 6   Diagnosed  ...        8
# 5   Diagnosed  ...        8
# 2   Diagnosed  ...        8
# 7   Diagnosed  ...        8
# 11  Diagnosed  ...        8
# 1   Diagnosed  ...        8
# 4   Diagnosed  ...        8
# 0   Diagnosed  ...        8
# 9   Diagnosed  ...        8
# 8   Diagnosed  ...        8
#
# [12 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...        9
# 2  Diagnosed  ...        9
# 0  Diagnosed  ...        9
# 4  Diagnosed  ...        9
# 3  Diagnosed  ...        9
#
# [5 rows x 5 columns]
#       status  ... to_event
# 3  Diagnosed  ...       10
# 1  Diagnosed  ...       10
# 2  Diagnosed  ...       10
# 0  Diagnosed  ...       10
#
# [4 rows x 5 columns]
# Input Patient Order Number: 3
# Patients probability: 0.4688515365123749
# Output predictions? (y/n): y
#       status  ... to_event
# 2  Diagnosed  ...        0
# 0  Diagnosed  ...        0
# 1  Diagnosed  ...        0
#
# [3 rows x 5 columns]
#        status  ... to_event
# 10  Diagnosed  ...        1
# 0   Diagnosed  ...        1
# 5   Diagnosed  ...        1
# 6   Diagnosed  ...        1
# 1   Diagnosed  ...        1
# 2   Diagnosed  ...        1
# 7   Diagnosed  ...        1
# 3   Diagnosed  ...        1
# 12  Diagnosed  ...        1
# 14  Diagnosed  ...        1
# 4   Diagnosed  ...        1
# 8   Diagnosed  ...        1
# 13  Diagnosed  ...        1
# 9   Diagnosed  ...        1
# 11  Diagnosed  ...        1
#
# [15 rows x 5 columns]
#       status  ... to_event
# 7  Diagnosed  ...        2
# 0  Diagnosed  ...        2
# 5  Diagnosed  ...        2
# 1  Diagnosed  ...        2
# 6  Diagnosed  ...        2
# 8  Diagnosed  ...        2
# 4  Diagnosed  ...        2
# 2  Diagnosed  ...        2
# 3  Diagnosed  ...        2
#
# [9 rows x 5 columns]
#        status  ... to_event
# 12  Diagnosed  ...        3
# 4   Diagnosed  ...        3
# 7   Diagnosed  ...        3
# 11  Diagnosed  ...        3
# 6   Diagnosed  ...        3
# 5   Diagnosed  ...        3
# 2   Diagnosed  ...        3
# 0   Diagnosed  ...        3
# 10  Diagnosed  ...        3
# 13  Diagnosed  ...        3
# 9   Diagnosed  ...        3
# 1   Diagnosed  ...        3
# 3   Diagnosed  ...        3
# 8   Diagnosed  ...        3
#
# [14 rows x 5 columns]
#        status  ... to_event
# 4   Diagnosed  ...        4
# 9   Diagnosed  ...        4
# 14  Diagnosed  ...        4
# 5   Diagnosed  ...        4
# 1   Diagnosed  ...        4
# 12  Diagnosed  ...        4
# 6   Diagnosed  ...        4
# 13  Diagnosed  ...        4
# 0   Diagnosed  ...        4
# 10  Diagnosed  ...        4
# 3   Diagnosed  ...        4
# 7   Diagnosed  ...        4
# 11  Diagnosed  ...        4
# 2   Diagnosed  ...        4
# 8   Diagnosed  ...        4
#
# [15 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...        5
# 1  Diagnosed  ...        5
# 2  Diagnosed  ...        5
# 4  Diagnosed  ...        5
# 6  Diagnosed  ...        5
# 3  Diagnosed  ...        5
# 5  Diagnosed  ...        5
#
# [7 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...        6
# 1  Diagnosed  ...        6
# 3  Diagnosed  ...        6
# 2  Diagnosed  ...        6
#
# [4 rows x 5 columns]
#       status  ... to_event
# 6  Diagnosed  ...        7
# 7  Diagnosed  ...        7
# 4  Diagnosed  ...        7
# 8  Diagnosed  ...        7
# 2  Diagnosed  ...        7
# 5  Diagnosed  ...        7
# 1  Diagnosed  ...        7
# 3  Diagnosed  ...        7
# 0  Diagnosed  ...        7
#
# [9 rows x 5 columns]
#        status  ... to_event
# 9   Diagnosed  ...        8
# 19  Diagnosed  ...        8
# 10  Diagnosed  ...        8
# 3   Diagnosed  ...        8
# 20  Diagnosed  ...        8
# 30  Diagnosed  ...        8
# 13  Diagnosed  ...        8
# 8   Diagnosed  ...        8
# 28  Diagnosed  ...        8
# 1   Diagnosed  ...        8
# 7   Diagnosed  ...        8
# 12  Diagnosed  ...        8
# 24  Diagnosed  ...        8
# 22  Diagnosed  ...        8
# 4   Diagnosed  ...        8
# 5   Diagnosed  ...        8
# 21  Diagnosed  ...        8
# 17  Diagnosed  ...        8
# 11  Diagnosed  ...        8
# 27  Diagnosed  ...        8
# 23  Diagnosed  ...        8
# 14  Diagnosed  ...        8
# 29  Diagnosed  ...        8
# 18  Diagnosed  ...        8
# 2   Diagnosed  ...        8
# 0   Diagnosed  ...        8
# 6   Diagnosed  ...        8
# 16  Diagnosed  ...        8
# 15  Diagnosed  ...        8
# 26  Diagnosed  ...        8
# 25  Diagnosed  ...        8
#
# [31 rows x 5 columns]
#        status  ... to_event
# 15  Diagnosed  ...        9
# 12  Diagnosed  ...        9
# 0   Diagnosed  ...        9
# 9   Diagnosed  ...        9
# 7   Diagnosed  ...        9
# 13  Diagnosed  ...        9
# 21  Diagnosed  ...        9
# 1   Diagnosed  ...        9
# 6   Diagnosed  ...        9
# 5   Diagnosed  ...        9
# 3   Diagnosed  ...        9
# 11  Diagnosed  ...        9
# 25  Diagnosed  ...        9
# 20  Diagnosed  ...        9
# 16  Diagnosed  ...        9
# 24  Diagnosed  ...        9
# 19  Diagnosed  ...        9
# 27  Diagnosed  ...        9
# 10  Diagnosed  ...        9
# 22  Diagnosed  ...        9
# 26  Diagnosed  ...        9
# 4   Diagnosed  ...        9
# 14  Diagnosed  ...        9
# 8   Diagnosed  ...        9
# 17  Diagnosed  ...        9
# 23  Diagnosed  ...        9
# 18  Diagnosed  ...        9
# 2   Diagnosed  ...        9
#
# [28 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       10
#
# [1 rows x 5 columns]
#        status  ... to_event
# 6   Diagnosed  ...       11
# 4   Diagnosed  ...       11
# 11  Diagnosed  ...       11
# 10  Diagnosed  ...       11
# 7   Diagnosed  ...       11
# 5   Diagnosed  ...       11
# 0   Diagnosed  ...       11
# 8   Diagnosed  ...       11
# 9   Diagnosed  ...       11
# 1   Diagnosed  ...       11
# 3   Diagnosed  ...       11
# 2   Diagnosed  ...       11
#
# [12 rows x 5 columns]
#        status  ... to_event
# 11  Diagnosed  ...       12
# 4   Diagnosed  ...       12
# 7   Diagnosed  ...       12
# 5   Diagnosed  ...       12
# 12  Diagnosed  ...       12
# 3   Diagnosed  ...       12
# 8   Diagnosed  ...       12
# 0   Diagnosed  ...       12
# 6   Diagnosed  ...       12
# 1   Diagnosed  ...       12
# 10  Diagnosed  ...       12
# 2   Diagnosed  ...       12
# 9   Diagnosed  ...       12
#
# [13 rows x 5 columns]
#        status  ... to_event
# 8   Diagnosed  ...       13
# 4   Diagnosed  ...       13
# 1   Diagnosed  ...       13
# 3   Diagnosed  ...       13
# 9   Diagnosed  ...       13
# 11  Diagnosed  ...       13
# 2   Diagnosed  ...       13
# 0   Diagnosed  ...       13
# 6   Diagnosed  ...       13
# 5   Diagnosed  ...       13
# 7   Diagnosed  ...       13
# 10  Diagnosed  ...       13
#
# [12 rows x 5 columns]
#        status  ... to_event
# 11  Diagnosed  ...       14
# 10  Diagnosed  ...       14
# 7   Diagnosed  ...       14
# 14  Diagnosed  ...       14
# 5   Diagnosed  ...       14
# 12  Diagnosed  ...       14
# 4   Diagnosed  ...       14
# 1   Diagnosed  ...       14
# 16  Diagnosed  ...       14
# 13  Diagnosed  ...       14
# 2   Diagnosed  ...       14
# 0   Diagnosed  ...       14
# 8   Diagnosed  ...       14
# 6   Diagnosed  ...       14
# 3   Diagnosed  ...       14
# 15  Diagnosed  ...       14
# 9   Diagnosed  ...       14
#
# [17 rows x 5 columns]
#        status  ... to_event
# 8   Diagnosed  ...       15
# 6   Diagnosed  ...       15
# 4   Diagnosed  ...       15
# 0   Diagnosed  ...       15
# 9   Diagnosed  ...       15
# 5   Diagnosed  ...       15
# 11  Diagnosed  ...       15
# 3   Diagnosed  ...       15
# 2   Diagnosed  ...       15
# 10  Diagnosed  ...       15
# 1   Diagnosed  ...       15
# 7   Diagnosed  ...       15
#
# [12 rows x 5 columns]
#        status  ... to_event
# 12  Diagnosed  ...       16
# 7   Diagnosed  ...       16
# 0   Diagnosed  ...       16
# 11  Diagnosed  ...       16
# 6   Diagnosed  ...       16
# 10  Diagnosed  ...       16
# 15  Diagnosed  ...       16
# 13  Diagnosed  ...       16
# 1   Diagnosed  ...       16
# 4   Diagnosed  ...       16
# 9   Diagnosed  ...       16
# 16  Diagnosed  ...       16
# 14  Diagnosed  ...       16
# 3   Diagnosed  ...       16
# 2   Diagnosed  ...       16
# 5   Diagnosed  ...       16
# 8   Diagnosed  ...       16
#
# [17 rows x 5 columns]
#        status  ... to_event
# 0   Diagnosed  ...       17
# 8   Diagnosed  ...       17
# 6   Diagnosed  ...       17
# 10  Diagnosed  ...       17
# 17  Diagnosed  ...       17
# 4   Diagnosed  ...       17
# 5   Diagnosed  ...       17
# 15  Diagnosed  ...       17
# 7   Diagnosed  ...       17
# 18  Diagnosed  ...       17
# 9   Diagnosed  ...       17
# 14  Diagnosed  ...       17
# 19  Diagnosed  ...       17
# 11  Diagnosed  ...       17
# 2   Diagnosed  ...       17
# 20  Diagnosed  ...       17
# 16  Diagnosed  ...       17
# 12  Diagnosed  ...       17
# 13  Diagnosed  ...       17
# 3   Diagnosed  ...       17
# 1   Diagnosed  ...       17
#
# [21 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...       18
# 0   Diagnosed  ...       18
# 11  Diagnosed  ...       18
# 10  Diagnosed  ...       18
# 18  Diagnosed  ...       18
# 17  Diagnosed  ...       18
# 12  Diagnosed  ...       18
# 4   Diagnosed  ...       18
# 6   Diagnosed  ...       18
# 13  Diagnosed  ...       18
# 16  Diagnosed  ...       18
# 9   Diagnosed  ...       18
# 15  Diagnosed  ...       18
# 5   Diagnosed  ...       18
# 2   Diagnosed  ...       18
# 8   Diagnosed  ...       18
# 3   Diagnosed  ...       18
# 7   Diagnosed  ...       18
# 14  Diagnosed  ...       18
#
# [19 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       19
# 1  Diagnosed  ...       19
#
# [2 rows x 5 columns]
#        status  ... to_event
# 24  Diagnosed  ...       20
# 21  Diagnosed  ...       20
# 14  Diagnosed  ...       20
# 26  Diagnosed  ...       20
# 16  Diagnosed  ...       20
# 15  Diagnosed  ...       20
# 22  Diagnosed  ...       20
# 9   Diagnosed  ...       20
# 23  Diagnosed  ...       20
# 13  Diagnosed  ...       20
# 2   Diagnosed  ...       20
# 18  Diagnosed  ...       20
# 7   Diagnosed  ...       20
# 17  Diagnosed  ...       20
# 5   Diagnosed  ...       20
# 6   Diagnosed  ...       20
# 4   Diagnosed  ...       20
# 25  Diagnosed  ...       20
# 1   Diagnosed  ...       20
# 20  Diagnosed  ...       20
# 3   Diagnosed  ...       20
# 19  Diagnosed  ...       20
# 8   Diagnosed  ...       20
# 12  Diagnosed  ...       20
# 0   Diagnosed  ...       20
# 11  Diagnosed  ...       20
# 10  Diagnosed  ...       20
#
# [27 rows x 5 columns]
#        status  ... to_event
# 3   Diagnosed  ...       21
# 7   Diagnosed  ...       21
# 5   Diagnosed  ...       21
# 8   Diagnosed  ...       21
# 9   Diagnosed  ...       21
# 11  Diagnosed  ...       21
# 12  Diagnosed  ...       21
# 1   Diagnosed  ...       21
# 6   Diagnosed  ...       21
# 13  Diagnosed  ...       21
# 4   Diagnosed  ...       21
# 0   Diagnosed  ...       21
# 10  Diagnosed  ...       21
# 2   Diagnosed  ...       21
#
# [14 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       22
# 5  Diagnosed  ...       22
# 2  Diagnosed  ...       22
# 3  Diagnosed  ...       22
# 4  Diagnosed  ...       22
# 0  Diagnosed  ...       22
#
# [6 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       23
# 1  Diagnosed  ...       23
#
# [2 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       24
# 0  Diagnosed  ...       24
# 2  Diagnosed  ...       24
#
# [3 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       25
# 4  Diagnosed  ...       25
# 6  Diagnosed  ...       25
# 3  Diagnosed  ...       25
# 5  Diagnosed  ...       25
# 0  Diagnosed  ...       25
# 2  Diagnosed  ...       25
#
# [7 rows x 5 columns]
#        status  ... to_event
# 4   Diagnosed  ...       26
# 1   Diagnosed  ...       26
# 5   Diagnosed  ...       26
# 18  Diagnosed  ...       26
# 10  Diagnosed  ...       26
# 11  Diagnosed  ...       26
# 0   Diagnosed  ...       26
# 12  Diagnosed  ...       26
# 2   Diagnosed  ...       26
# 15  Diagnosed  ...       26
# 9   Diagnosed  ...       26
# 16  Diagnosed  ...       26
# 8   Diagnosed  ...       26
# 13  Diagnosed  ...       26
# 17  Diagnosed  ...       26
# 3   Diagnosed  ...       26
# 7   Diagnosed  ...       26
# 14  Diagnosed  ...       26
# 6   Diagnosed  ...       26
#
# [19 rows x 5 columns]
#        status  ... to_event
# 4   Diagnosed  ...       27
# 0   Diagnosed  ...       27
# 9   Diagnosed  ...       27
# 8   Diagnosed  ...       27
# 6   Diagnosed  ...       27
# 1   Diagnosed  ...       27
# 7   Diagnosed  ...       27
# 12  Diagnosed  ...       27
# 5   Diagnosed  ...       27
# 13  Diagnosed  ...       27
# 11  Diagnosed  ...       27
# 2   Diagnosed  ...       27
# 10  Diagnosed  ...       27
# 3   Diagnosed  ...       27
#
# [14 rows x 5 columns]
#       status  ... to_event
# 7  Diagnosed  ...       28
# 6  Diagnosed  ...       28
# 1  Diagnosed  ...       28
# 3  Diagnosed  ...       28
# 9  Diagnosed  ...       28
# 4  Diagnosed  ...       28
# 0  Diagnosed  ...       28
# 5  Diagnosed  ...       28
# 8  Diagnosed  ...       28
# 2  Diagnosed  ...       28
#
# [10 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       29
# 4  Diagnosed  ...       29
# 0  Diagnosed  ...       29
# 2  Diagnosed  ...       29
# 3  Diagnosed  ...       29
#
# [5 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...       30
# 5  Diagnosed  ...       30
# 0  Diagnosed  ...       30
# 2  Diagnosed  ...       30
# 6  Diagnosed  ...       30
# 7  Diagnosed  ...       30
# 8  Diagnosed  ...       30
# 3  Diagnosed  ...       30
# 4  Diagnosed  ...       30
#
# [9 rows x 5 columns]
#        status  ... to_event
# 11  Diagnosed  ...       31
# 5   Diagnosed  ...       31
# 10  Diagnosed  ...       31
# 8   Diagnosed  ...       31
# 16  Diagnosed  ...       31
# 0   Diagnosed  ...       31
# 12  Diagnosed  ...       31
# 15  Diagnosed  ...       31
# 7   Diagnosed  ...       31
# 1   Diagnosed  ...       31
# 13  Diagnosed  ...       31
# 14  Diagnosed  ...       31
# 9   Diagnosed  ...       31
# 6   Diagnosed  ...       31
# 2   Diagnosed  ...       31
# 4   Diagnosed  ...       31
# 3   Diagnosed  ...       31
#
# [17 rows x 5 columns]
#       status  ... to_event
# 4  Diagnosed  ...       32
# 2  Diagnosed  ...       32
# 5  Diagnosed  ...       32
# 3  Diagnosed  ...       32
# 0  Diagnosed  ...       32
# 1  Diagnosed  ...       32
#
# [6 rows x 5 columns]
#        status  ... to_event
# 0   Diagnosed  ...       33
# 3   Diagnosed  ...       33
# 4   Diagnosed  ...       33
# 2   Diagnosed  ...       33
# 9   Diagnosed  ...       33
# 6   Diagnosed  ...       33
# 1   Diagnosed  ...       33
# 5   Diagnosed  ...       33
# 8   Diagnosed  ...       33
# 7   Diagnosed  ...       33
# 10  Diagnosed  ...       33
#
# [11 rows x 5 columns]
#        status  ... to_event
# 21  Diagnosed  ...       34
# 20  Diagnosed  ...       34
# 15  Diagnosed  ...       34
# 6   Diagnosed  ...       34
# 10  Diagnosed  ...       34
# 14  Diagnosed  ...       34
# 16  Diagnosed  ...       34
# 7   Diagnosed  ...       34
# 3   Diagnosed  ...       34
# 11  Diagnosed  ...       34
# 17  Diagnosed  ...       34
# 19  Diagnosed  ...       34
# 13  Diagnosed  ...       34
# 4   Diagnosed  ...       34
# 5   Diagnosed  ...       34
# 18  Diagnosed  ...       34
# 9   Diagnosed  ...       34
# 0   Diagnosed  ...       34
# 12  Diagnosed  ...       34
# 8   Diagnosed  ...       34
# 1   Diagnosed  ...       34
# 2   Diagnosed  ...       34
#
# [22 rows x 5 columns]
#       status  ... to_event
# 4  Diagnosed  ...       35
# 5  Diagnosed  ...       35
# 6  Diagnosed  ...       35
# 2  Diagnosed  ...       35
# 7  Diagnosed  ...       35
# 0  Diagnosed  ...       35
# 3  Diagnosed  ...       35
# 8  Diagnosed  ...       35
# 1  Diagnosed  ...       35
#
# [9 rows x 5 columns]
#        status  ... to_event
# 11  Diagnosed  ...       36
# 6   Diagnosed  ...       36
# 9   Diagnosed  ...       36
# 10  Diagnosed  ...       36
# 3   Diagnosed  ...       36
# 1   Diagnosed  ...       36
# 7   Diagnosed  ...       36
# 2   Diagnosed  ...       36
# 8   Diagnosed  ...       36
# 4   Diagnosed  ...       36
# 5   Diagnosed  ...       36
# 0   Diagnosed  ...       36
#
# [12 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       37
#
# [1 rows x 5 columns]
#        status  ... to_event
# 7   Diagnosed  ...       38
# 4   Diagnosed  ...       38
# 2   Diagnosed  ...       38
# 1   Diagnosed  ...       38
# 9   Diagnosed  ...       38
# 5   Diagnosed  ...       38
# 8   Diagnosed  ...       38
# 0   Diagnosed  ...       38
# 12  Diagnosed  ...       38
# 6   Diagnosed  ...       38
# 13  Diagnosed  ...       38
# 3   Diagnosed  ...       38
# 11  Diagnosed  ...       38
# 10  Diagnosed  ...       38
#
# [14 rows x 5 columns]
#       status  ... to_event
# 9  Diagnosed  ...       39
# 7  Diagnosed  ...       39
# 8  Diagnosed  ...       39
# 4  Diagnosed  ...       39
# 2  Diagnosed  ...       39
# 3  Diagnosed  ...       39
# 1  Diagnosed  ...       39
# 5  Diagnosed  ...       39
# 0  Diagnosed  ...       39
# 6  Diagnosed  ...       39
#
# [10 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       40
# 1  Diagnosed  ...       40
#
# [2 rows x 5 columns]
#       status  ... to_event
# 4  Diagnosed  ...       41
# 0  Diagnosed  ...       41
# 5  Diagnosed  ...       41
# 1  Diagnosed  ...       41
# 3  Diagnosed  ...       41
# 2  Diagnosed  ...       41
#
# [6 rows x 5 columns]
#       status  ... to_event
# 4  Diagnosed  ...       42
# 5  Diagnosed  ...       42
# 1  Diagnosed  ...       42
# 0  Diagnosed  ...       42
# 3  Diagnosed  ...       42
# 9  Diagnosed  ...       42
# 6  Diagnosed  ...       42
# 2  Diagnosed  ...       42
# 7  Diagnosed  ...       42
# 8  Diagnosed  ...       42
#
# [10 rows x 5 columns]
#        status  ... to_event
# 1   Diagnosed  ...       43
# 8   Diagnosed  ...       43
# 13  Diagnosed  ...       43
# 12  Diagnosed  ...       43
# 0   Diagnosed  ...       43
# 14  Diagnosed  ...       43
# 11  Diagnosed  ...       43
# 3   Diagnosed  ...       43
# 2   Diagnosed  ...       43
# 9   Diagnosed  ...       43
# 4   Diagnosed  ...       43
# 7   Diagnosed  ...       43
# 5   Diagnosed  ...       43
# 10  Diagnosed  ...       43
# 6   Diagnosed  ...       43
#
# [15 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...       44
# 3  Diagnosed  ...       44
# 0  Diagnosed  ...       44
# 1  Diagnosed  ...       44
#
# [4 rows x 5 columns]
#       status  ... to_event
# 6  Diagnosed  ...       45
# 4  Diagnosed  ...       45
# 7  Diagnosed  ...       45
# 9  Diagnosed  ...       45
# 2  Diagnosed  ...       45
# 0  Diagnosed  ...       45
# 5  Diagnosed  ...       45
# 1  Diagnosed  ...       45
# 3  Diagnosed  ...       45
# 8  Diagnosed  ...       45
#
# [10 rows x 5 columns]
#       status  ... to_event
# 2  Diagnosed  ...       46
# 1  Diagnosed  ...       46
# 8  Diagnosed  ...       46
# 0  Diagnosed  ...       46
# 3  Diagnosed  ...       46
# 7  Diagnosed  ...       46
# 5  Diagnosed  ...       46
# 4  Diagnosed  ...       46
# 6  Diagnosed  ...       46
#
# [9 rows x 5 columns]
#        status  ... to_event
# 15  Diagnosed  ...       47
# 11  Diagnosed  ...       47
# 3   Diagnosed  ...       47
# 2   Diagnosed  ...       47
# 14  Diagnosed  ...       47
# 16  Diagnosed  ...       47
# 9   Diagnosed  ...       47
# 0   Diagnosed  ...       47
# 1   Diagnosed  ...       47
# 6   Diagnosed  ...       47
# 5   Diagnosed  ...       47
# 10  Diagnosed  ...       47
# 13  Diagnosed  ...       47
# 8   Diagnosed  ...       47
# 7   Diagnosed  ...       47
# 12  Diagnosed  ...       47
# 4   Diagnosed  ...       47
#
# [17 rows x 5 columns]
#        status  ... to_event
# 4   Diagnosed  ...       48
# 13  Diagnosed  ...       48
# 0   Diagnosed  ...       48
# 1   Diagnosed  ...       48
# 6   Diagnosed  ...       48
# 11  Diagnosed  ...       48
# 5   Diagnosed  ...       48
# 15  Diagnosed  ...       48
# 7   Diagnosed  ...       48
# 10  Diagnosed  ...       48
# 14  Diagnosed  ...       48
# 2   Diagnosed  ...       48
# 16  Diagnosed  ...       48
# 3   Diagnosed  ...       48
# 9   Diagnosed  ...       48
# 17  Diagnosed  ...       48
# 8   Diagnosed  ...       48
# 12  Diagnosed  ...       48
#
# [18 rows x 5 columns]
#       status  ... to_event
# 0  Diagnosed  ...       49
#
# [1 rows x 5 columns]
# Empty DataFrame
# Columns: [status, feature, importance_feature, importance_visit, to_event]
# Index: []
# Input Patient Order Number: 1
# Patients probability: 0.8320015668869019
# Output predictions? (y/n): y
#       status  ... to_event
# 6  Diagnosed  ...        0
# 4  Diagnosed  ...        0
# 2  Diagnosed  ...        0
# 1  Diagnosed  ...        0
# 0  Diagnosed  ...        0
# 5  Diagnosed  ...        0
# 3  Diagnosed  ...        0
# 7  Diagnosed  ...        0
#
# [8 rows x 5 columns]
#       status  ... to_event
# 3  Diagnosed  ...        1
# 0  Diagnosed  ...        1
# 1  Diagnosed  ...        1
# 2  Diagnosed  ...        1
# 5  Diagnosed  ...        1
# 6  Diagnosed  ...        1
# 4  Diagnosed  ...        1
#
# [7 rows x 5 columns]
#       status  ... to_event
# 7  Diagnosed  ...        2
# 5  Diagnosed  ...        2
# 1  Diagnosed  ...        2
# 4  Diagnosed  ...        2
# 0  Diagnosed  ...        2
# 2  Diagnosed  ...        2
# 6  Diagnosed  ...        2
# 3  Diagnosed  ...        2
#
# [8 rows x 5 columns]
#        status  ... to_event
# 6   Diagnosed  ...        3
# 3   Diagnosed  ...        3
# 11  Diagnosed  ...        3
# 4   Diagnosed  ...        3
# 0   Diagnosed  ...        3
# 1   Diagnosed  ...        3
# 9   Diagnosed  ...        3
# 10  Diagnosed  ...        3
# 7   Diagnosed  ...        3
# 5   Diagnosed  ...        3
# 2   Diagnosed  ...        3
# 8   Diagnosed  ...        3
#
# [12 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...        4
# 4  Diagnosed  ...        4
# 0  Diagnosed  ...        4
# 6  Diagnosed  ...        4
# 2  Diagnosed  ...        4
# 5  Diagnosed  ...        4
# 3  Diagnosed  ...        4
#
# [7 rows x 5 columns]
#       status  ... to_event
# 1  Diagnosed  ...        5
# 0  Diagnosed  ...        5
#
# [2 rows x 5 columns]
# Input Patient Order Number:
